# %% [markdown]
# # Faster R-CNN Detection
# Este Notebook es parte de un proyecto que se puede encontrar [aqui](https://github.com/nel-eleven11/Proyecto2_DataScience), donde se busca diseñar una aplicación de datos para comparar e interactuar con diferentes modelos de visión por computadora. Primero, vamos a empezar instalando las librerías requeridas que incluyen

# %%
import polars as pl
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision.models.detection import retinanet_resnet50_fpn
import torchvision.transforms as T
from PIL import Image
import os

# %% [markdown]
# ## Pre-Procesamiento
# A pesar de ya haber realizado un EDA, todavía debemos de preparar los datos en un formato soportado por YoloV8. Primero, vamos a empezar cargando los datos de nuestro dataset.

# %% [markdown]
# ### Carga de Datos
# Al trabajar dentro de Kaggle, podemos importar los datos y los outputs del Notebook de limpieza. Podemos revisar los directorios rápidamente

# %%
import os
print(os.listdir("/kaggle/input"))
# Out:
# ['mosquito-data', '00-eda-and-cleaning']

# %% [markdown]
# Luego, podemos setear algunas variables que nos serán de utilidad para saber dónde se encuentra la información.

# %%
RAW_DATA_PATH = "/kaggle/input/mosquito-data"
EDA_OUTPUT_PATH = "/kaggle/input/00-eda-and-cleaning"

print("raw:", os.listdir(RAW_DATA_PATH))
print("eda:", os.listdir(EDA_OUTPUT_PATH))
# Out:
# raw: ['train_images', 'sample_submission_phase1 (1).csv', 'test_images_phase1', 'test_phase1.csv', 'train.csv']
# eda: ['__results__.html', 'val.csv', '__notebook__.ipynb', '__results___files', '__output__.json', 'train.csv', 'test.csv', 'custom.css']

# %% [markdown]
# Podemos ver por los resultados, que tenemos cargados ya los resultados de la limpieza en EDA_OUTPUT_PATH/train.csv, test.csv y val.csv respectivamente. Adicionalmente, las imágenes que utilizaremos se encuentran en RAW_DATA_PATH/train_images. Podemos cargar los datos hacia DataFrames utilizando Polars.

# %%
# Where the training images actually are
image_dir = os.path.join(RAW_DATA_PATH, "train_images")
print("image_dir:", image_dir)

# Optional: where to save trained models/checkpoints
MODEL_OUTPUT_DIR = "/kaggle/working/retinanet_checkpoints"
os.makedirs(MODEL_OUTPUT_DIR, exist_ok=True)
print("MODEL_OUTPUT_DIR:", MODEL_OUTPUT_DIR)
# Out:
# image_dir: /kaggle/input/mosquito-data/train_images
# MODEL_OUTPUT_DIR: /kaggle/working/retinanet_checkpoints

# %%
train_df = pl.read_csv(os.path.join(EDA_OUTPUT_PATH, "train.csv"))
val_df   = pl.read_csv(os.path.join(EDA_OUTPUT_PATH, "val.csv"))
test_df  = pl.read_csv(os.path.join(EDA_OUTPUT_PATH, "test.csv"))

print("train shape:", train_df.shape)
print("val shape  :", val_df.shape)
print("test shape :", test_df.shape)

print("Columns:", train_df.columns)
print("Class labels:", train_df.select("class_label").unique())
# Out:
# train shape: (6396, 8)
# val shape  : (800, 8)
# test shape : (800, 8)
# Columns: ['img_fName', 'img_w', 'img_h', 'bbx_xtl', 'bbx_ytl', 'bbx_xbr', 'bbx_ybr', 'class_label']
# Class labels: shape: (6, 1)
# ┌────────────────────┐
# │ class_label        │
# │ ---                │
# │ str                │
# ╞════════════════════╡
# │ aegypti            │
# │ japonicus/koreicus │
# │ culiseta           │
# │ anopheles          │
# │ albopictus         │
# │ culex              │
# └────────────────────┘

# %% [markdown]
# Luego del sanity check, podemos confirmar que los datos fueron cargados exitosamente. Ahora, Yolo espera que las clases sean mappeadas de manera numérica.

# %%
# Map string labels -> ints starting at 1 (0 reserved for background)
classes = sorted(
    train_df.select("class_label")
            .unique()["class_label"]
            .to_list()
)
print("classes:", classes)

class_to_id = {cls: i for i, cls in enumerate(classes, start=1)}
print("class_to_id:", class_to_id)

# For RetinaNet / torchvision detection models (background + N classes)
num_classes = len(classes) + 1
print("num_classes (for RetinaNet):", num_classes)

train_df = train_df.with_columns(
    pl.col("class_label")
      .replace(class_to_id)
      .cast(pl.Int64)
      .alias("class_id")
)

val_df = val_df.with_columns(
    pl.col("class_label")
      .replace(class_to_id)
      .cast(pl.Int64)
      .alias("class_id")
)

test_df = test_df.with_columns(
    pl.col("class_label")
      .replace(class_to_id)
      .cast(pl.Int64)
      .alias("class_id")
)

train_df.head()
# Out:
# classes: ['aegypti', 'albopictus', 'anopheles', 'culex', 'culiseta', 'japonicus/koreicus']
# class_to_id: {'aegypti': 1, 'albopictus': 2, 'anopheles': 3, 'culex': 4, 'culiseta': 5, 'japonicus/koreicus': 6}
# num_classes (for RetinaNet): 7
# shape: (5, 9)
# ┌───────────────────────┬───────┬───────┬─────────┬───┬─────────┬─────────┬─────────────┬──────────┐
# │ img_fName             ┆ img_w ┆ img_h ┆ bbx_xtl ┆ … ┆ bbx_xbr ┆ bbx_ybr ┆ class_label ┆ class_id │
# │ ---                   ┆ ---   ┆ ---   ┆ ---     ┆   ┆ ---     ┆ ---     ┆ ---         ┆ ---      │
# │ str                   ┆ i64   ┆ i64   ┆ i64     ┆   ┆ i64     ┆ i64     ┆ str         ┆ i64      │
# ╞═══════════════════════╪═══════╪═══════╪═════════╪═══╪═════════╪═════════╪═════════════╪══════════╡
# │ 92715872-3287-4bff-aa ┆ 2448  ┆ 3264  ┆ 1301    ┆ … ┆ 1641    ┆ 2096    ┆ albopictus  ┆ 2        │
# │ 61-704797…            ┆       ┆       ┆         ┆   ┆         ┆         ┆             ┆          │
# │ 82df4b68-0f45-4afe-92 ┆ 768   ┆ 1024  ┆ 220     ┆ … ┆ 659     ┆ 808     ┆ albopictus  ┆ 2        │
# │ 15-48488b…            ┆       ┆       ┆         ┆   ┆         ┆         ┆             ┆          │
# │ 331ad30a-7564-4478-b8 ┆ 3456  ┆ 4608  ┆ 1169    ┆ … ┆ 1586    ┆ 2826    ┆ albopictus  ┆ 2        │
# │ 63-7bc760…            ┆       ┆       ┆         ┆   ┆         ┆         ┆             ┆          │
# │ 46f34803-f754-457d-bd ┆ 1152  ┆ 2560  ┆ 198     ┆ … ┆ 954     ┆ 1351    ┆ albopictus  ┆ 2        │
# │ b7-e581d3…            ┆       ┆       ┆         ┆   ┆         ┆         ┆             ┆          │
# │ 5792dd8b-e690-4c3a-b0 ┆ 3072  ┆ 4080  ┆ 1104    ┆ … ┆ 2458    ┆ 2911    ┆ anopheles   ┆ 3        │
# │ 61-a375ab…            ┆       ┆       ┆         ┆   ┆         ┆         ┆             ┆          │
# └───────────────────────┴───────┴───────┴─────────┴───┴─────────┴─────────┴─────────────┴──────────┘

# %% [markdown]
# ### Carga a Datset de Torch y Transformaciones
# El modelo de RetinaNet espera un tipo Dataset de Torch, por lo que debemos transformar nuestros datos ligeramente.

# %%
import os
import cv2

import torch
from torch.utils.data import Dataset, DataLoader

import albumentations as A
from albumentations.pytorch import ToTensorV2

# %%
IMG_SIZE = 640

train_tf = A.Compose(
    [
        A.Resize(IMG_SIZE, IMG_SIZE),
        A.HorizontalFlip(p=0.5),
        A.RandomBrightnessContrast(p=0.2),
        A.Normalize(mean=(0.485, 0.456, 0.406),
                    std=(0.229, 0.224, 0.225)),
        ToTensorV2(),
    ],
    bbox_params=A.BboxParams(
        format="pascal_voc",
        label_fields=["labels"],
    ),
)

val_tf = A.Compose(
    [
        A.Resize(IMG_SIZE, IMG_SIZE),
        A.Normalize(mean=(0.485, 0.456, 0.406),
                    std=(0.229, 0.224, 0.225)),
        ToTensorV2(),
    ],
    bbox_params=A.BboxParams(
        format="pascal_voc",
        label_fields=["labels"],
    ),
)

# %%
class RCNN_Dataset(Dataset):
    def __init__(self, df_pl, img_dir, transforms=None):
        """
        df_pl: Polars DataFrame with columns:
            img_fName, bbx_xtl, bbx_ytl, bbx_xbr, bbx_ybr, class_id
            (1 row per bbox)
        """
        self.df = df_pl.to_pandas()
        self.img_dir = img_dir
        self.transforms = transforms
        self.image_ids = self.df["img_fName"].unique()

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        image_id = self.image_ids[idx]
        records = self.df[self.df["img_fName"] == image_id]

        img_path = os.path.join(self.img_dir, image_id)
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        boxes = records[["bbx_xtl", "bbx_ytl", "bbx_xbr", "bbx_ybr"]].values.astype("float32")
        labels = records["class_id"].values.astype("int64")  # already 1..N

        if self.transforms is not None:
            transformed = self.transforms(
                image=image,
                bboxes=boxes,
                labels=labels,
            )
            image = transformed["image"]      # tensor CxHxW
            boxes = transformed["bboxes"]
            labels = transformed["labels"]

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)

        target = {
            "boxes": boxes,
            "labels": labels,
        }
        return image, target

# %%
def collate_fn(batch):
    return tuple(zip(*batch))

# %%
train_dataset = RCNN_Dataset(
    df_pl=train_df,
    img_dir=image_dir,
    transforms=train_tf,
)

val_dataset = RCNN_Dataset(
    df_pl=val_df,
    img_dir=image_dir,
    transforms=val_tf,
)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=4,        # bump up/down depending on VRAM
    shuffle=True,
    num_workers=2,
    collate_fn=collate_fn,
)

val_loader = DataLoader(
    val_dataset,
    batch_size=16,
    shuffle=False,
    num_workers=2,
    collate_fn=collate_fn,
)

print("train batches:", len(train_loader))
print("val batches:", len(val_loader))
# Out:
# train batches: 1599
# val batches: 50

# %%
import torch
from torchvision.models.detection import fasterrcnn_resnet50_fpn

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

# Faster R-CNN with ResNet-50 FPN, trained from scratch
model = fasterrcnn_resnet50_fpn(
    weights=None,           # no COCO pretrained detector
    num_classes=num_classes # same num_classes you already computed
).to(device)
# Out:
# device: cuda
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 205MB/s]

# %%
import torch

optimizer = torch.optim.SGD(
    model.parameters(),
    lr=0.001,      # slower LR than 0.005
    momentum=0.9,
    weight_decay=0.0005,
)

lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=8,  # decay after 15 epochs
    gamma=0.1,     # LR: 0.001 -> 0.0001
)

print("Optimizer and LR scheduler ready.")
# Out:
# Optimizer and LR scheduler ready.

# %%
import time

num_epochs=16

history = []
start_time = time.time()

num_batches = len(train_loader)
# log about 10 times per epoch max
log_interval = max(1, num_batches // 10)

print(f"Starting training for {num_epochs} epochs "
      f"({num_batches} batches/epoch, log_interval={log_interval})")

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    loss_components_sum = {}
    epoch_start = time.time()

    print(f"\n===== Epoch {epoch+1}/{num_epochs} =====")

    for batch_idx, (images, targets) in enumerate(train_loader):
        images  = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)
        loss = sum(loss for loss in loss_dict.values())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_value = loss.item()
        running_loss += loss_value

        for k, v in loss_dict.items():
            loss_components_sum[k] = loss_components_sum.get(k, 0.0) + v.item()

        # periodic batch logging (visible in Kaggle logs, but not spammy)
        if (batch_idx + 1) % log_interval == 0 or (batch_idx + 1) == num_batches:
            avg_so_far = running_loss / (batch_idx + 1)
            print(
                f"  [Epoch {epoch+1}/{num_epochs}] "
                f"Batch {batch_idx+1}/{num_batches} "
                f"- batch_loss: {loss_value:.4f} "
                f"- avg_loss_so_far: {avg_so_far:.4f}"
            )

    epoch_time = time.time() - epoch_start
    epoch_loss = running_loss / num_batches
    epoch_components = {
        k: v / num_batches for k, v in loss_components_sum.items()
    }
    current_lr = optimizer.param_groups[0]["lr"]

    print(
        f"Epoch [{epoch+1}/{num_epochs}] "
        f"- epoch_loss: {epoch_loss:.4f} "
        f"- time: {epoch_time:.1f}s "
        f"- lr: {current_lr:.6f}"
    )
    if epoch_components:
        comp_str = " | ".join(f"{k}: {v:.4f}" for k, v in epoch_components.items())
        print("  components:", comp_str)

    lr_scheduler.step()

    history.append(
        {
            "epoch": epoch + 1,
            "epoch_loss": epoch_loss,
            "epoch_time_sec": epoch_time,
            "lr": current_lr,
            "loss_components": epoch_components,
        }
    )

total_time = time.time() - start_time
print(f"\nTotal training time: {total_time/60:.2f} minutes")
# Out:
# Starting training for 16 epochs (1599 batches/epoch, log_interval=159)
#
# ===== Epoch 1/16 =====
#   [Epoch 1/16] Batch 159/1599 - batch_loss: 0.1508 - avg_loss_so_far: 0.3200
#   [Epoch 1/16] Batch 318/1599 - batch_loss: 0.1620 - avg_loss_so_far: 0.2633
#   [Epoch 1/16] Batch 477/1599 - batch_loss: 0.2047 - avg_loss_so_far: 0.2404
#   [Epoch 1/16] Batch 636/1599 - batch_loss: 0.2075 - avg_loss_so_far: 0.2281
#   [Epoch 1/16] Batch 795/1599 - batch_loss: 0.2470 - avg_loss_so_far: 0.2194
#   [Epoch 1/16] Batch 954/1599 - batch_loss: 0.2321 - avg_loss_so_far: 0.2131
#   [Epoch 1/16] Batch 1113/1599 - batch_loss: 0.1639 - avg_loss_so_far: 0.2089
#   [Epoch 1/16] Batch 1272/1599 - batch_loss: 0.2004 - avg_loss_so_far: 0.2059
#   [Epoch 1/16] Batch 1431/1599 - batch_loss: 0.1886 - avg_loss_so_far: 0.2037
#   [Epoch 1/16] Batch 1590/1599 - batch_loss: 0.2345 - avg_loss_so_far: 0.2015
#   [Epoch 1/16] Batch 1599/1599 - batch_loss: 0.1721 - avg_loss_so_far: 0.2015
# Epoch [1/16] - epoch_loss: 0.2015 - time: 1443.5s - lr: 0.001000
#   components: loss_classifier: 0.0965 | loss_box_reg: 0.0836 | loss_objectness: 0.0164 | loss_rpn_box_reg: 0.0049
#
# ===== Epoch 2/16 =====
#   [Epoch 2/16] Batch 159/1599 - batch_loss: 0.1479 - avg_loss_so_far: 0.1791
#   [Epoch 2/16] Batch 318/1599 - batch_loss: 0.1663 - avg_loss_so_far: 0.1718
#   [Epoch 2/16] Batch 477/1599 - batch_loss: 0.1247 - avg_loss_so_far: 0.1703
#   [Epoch 2/16] Batch 636/1599 - batch_loss: 0.1313 - avg_loss_so_far: 0.1696
#   [Epoch 2/16] Batch 795/1599 - batch_loss: 0.1603 - avg_loss_so_far: 0.1685
#   [Epoch 2/16] Batch 954/1599 - batch_loss: 0.2112 - avg_loss_so_far: 0.1675
#   [Epoch 2/16] Batch 1113/1599 - batch_loss: 0.1379 - avg_loss_so_far: 0.1665
#   [Epoch 2/16] Batch 1272/1599 - batch_loss: 0.1323 - avg_loss_so_far: 0.1660
#   [Epoch 2/16] Batch 1431/1599 - batch_loss: 0.1622 - avg_loss_so_far: 0.1655
#   [Epoch 2/16] Batch 1590/1599 - batch_loss: 0.2157 - avg_loss_so_far: 0.1646
#   [Epoch 2/16] Batch 1599/1599 - batch_loss: 0.1495 - avg_loss_so_far: 0.1646
# Epoch [2/16] - epoch_loss: 0.1646 - time: 1459.3s - lr: 0.001000
#   components: loss_classifier: 0.0760 | loss_box_reg: 0.0799 | loss_objectness: 0.0052 | loss_rpn_box_reg: 0.0036
#
# ===== Epoch 3/16 =====
#   [Epoch 3/16] Batch 159/1599 - batch_loss: 0.1694 - avg_loss_so_far: 0.1559
#   [Epoch 3/16] Batch 318/1599 - batch_loss: 0.1647 - avg_loss_so_far: 0.1544
#   [Epoch 3/16] Batch 477/1599 - batch_loss: 0.2366 - avg_loss_so_far: 0.1545
#   [Epoch 3/16] Batch 636/1599 - batch_loss: 0.1672 - avg_loss_so_far: 0.1535
#   [Epoch 3/16] Batch 795/1599 - batch_loss: 0.1582 - avg_loss_so_far: 0.1537
#   [Epoch 3/16] Batch 954/1599 - batch_loss: 0.1877 - avg_loss_so_far: 0.1545
#   [Epoch 3/16] Batch 1113/1599 - batch_loss: 0.2437 - avg_loss_so_far: 0.1526
#   [Epoch 3/16] Batch 1272/1599 - batch_loss: 0.0872 - avg_loss_so_far: 0.1514
#   [Epoch 3/16] Batch 1431/1599 - batch_loss: 0.2112 - avg_loss_so_far: 0.1507
#   [Epoch 3/16] Batch 1590/1599 - batch_loss: 0.1035 - avg_loss_so_far: 0.1499
#   [Epoch 3/16] Batch 1599/1599 - batch_loss: 0.0867 - avg_loss_so_far: 0.1499
# Epoch [3/16] - epoch_loss: 0.1499 - time: 1457.8s - lr: 0.001000
#   components: loss_classifier: 0.0673 | loss_box_reg: 0.0755 | loss_objectness: 0.0042 | loss_rpn_box_reg: 0.0029
#
# ===== Epoch 4/16 =====
#   [Epoch 4/16] Batch 159/1599 - batch_loss: 0.1354 - avg_loss_so_far: 0.1404
#   [Epoch 4/16] Batch 318/1599 - batch_loss: 0.1903 - avg_loss_so_far: 0.1388
#   [Epoch 4/16] Batch 477/1599 - batch_loss: 0.1667 - avg_loss_so_far: 0.1398
#   [Epoch 4/16] Batch 636/1599 - batch_loss: 0.1064 - avg_loss_so_far: 0.1393
#   [Epoch 4/16] Batch 795/1599 - batch_loss: 0.1320 - avg_loss_so_far: 0.1384
#   [Epoch 4/16] Batch 954/1599 - batch_loss: 0.1244 - avg_loss_so_far: 0.1379
#   [Epoch 4/16] Batch 1113/1599 - batch_loss: 0.1397 - avg_loss_so_far: 0.1374
#   [Epoch 4/16] Batch 1272/1599 - batch_loss: 0.1600 - avg_loss_so_far: 0.1376
#   [Epoch 4/16] Batch 1431/1599 - batch_loss: 0.0856 - avg_loss_so_far: 0.1370
#   [Epoch 4/16] Batch 1590/1599 - batch_loss: 0.1624 - avg_loss_so_far: 0.1363
#   [Epoch 4/16] Batch 1599/1599 - batch_loss: 0.0953 - avg_loss_so_far: 0.1362
# Epoch [4/16] - epoch_loss: 0.1362 - time: 1458.9s - lr: 0.001000
#   components: loss_classifier: 0.0607 | loss_box_reg: 0.0693 | loss_objectness: 0.0037 | loss_rpn_box_reg: 0.0025
#
# ===== Epoch 5/16 =====
#   [Epoch 5/16] Batch 159/1599 - batch_loss: 0.1474 - avg_loss_so_far: 0.1234
#   [Epoch 5/16] Batch 318/1599 - batch_loss: 0.1420 - avg_loss_so_far: 0.1253
#   [Epoch 5/16] Batch 477/1599 - batch_loss: 0.1383 - avg_loss_so_far: 0.1268
#   [Epoch 5/16] Batch 636/1599 - batch_loss: 0.1596 - avg_loss_so_far: 0.1268
#   [Epoch 5/16] Batch 795/1599 - batch_loss: 0.0815 - avg_loss_so_far: 0.1269
#   [Epoch 5/16] Batch 954/1599 - batch_loss: 0.1065 - avg_loss_so_far: 0.1272
#   [Epoch 5/16] Batch 1113/1599 - batch_loss: 0.1255 - avg_loss_so_far: 0.1266
#   [Epoch 5/16] Batch 1272/1599 - batch_loss: 0.1630 - avg_loss_so_far: 0.1274
#   [Epoch 5/16] Batch 1431/1599 - batch_loss: 0.1145 - avg_loss_so_far: 0.1277
#   [Epoch 5/16] Batch 1590/1599 - batch_loss: 0.1398 - avg_loss_so_far: 0.1280
#   [Epoch 5/16] Batch 1599/1599 - batch_loss: 0.1203 - avg_loss_so_far: 0.1279
# Epoch [5/16] - epoch_loss: 0.1279 - time: 1459.3s - lr: 0.001000
#   components: loss_classifier: 0.0575 | loss_box_reg: 0.0649 | loss_objectness: 0.0033 | loss_rpn_box_reg: 0.0023
#
# ===== Epoch 6/16 =====
#   [Epoch 6/16] Batch 159/1599 - batch_loss: 0.2051 - avg_loss_so_far: 0.1220
#   [Epoch 6/16] Batch 318/1599 - batch_loss: 0.1793 - avg_loss_so_far: 0.1217
#   [Epoch 6/16] Batch 477/1599 - batch_loss: 0.0735 - avg_loss_so_far: 0.1224
#   [Epoch 6/16] Batch 636/1599 - batch_loss: 0.1671 - avg_loss_so_far: 0.1227
#   [Epoch 6/16] Batch 795/1599 - batch_loss: 0.0954 - avg_loss_so_far: 0.1241
#   [Epoch 6/16] Batch 954/1599 - batch_loss: 0.1013 - avg_loss_so_far: 0.1232
#   [Epoch 6/16] Batch 1113/1599 - batch_loss: 0.1128 - avg_loss_so_far: 0.1230
#   [Epoch 6/16] Batch 1272/1599 - batch_loss: 0.0704 - avg_loss_so_far: 0.1220
#   [Epoch 6/16] Batch 1431/1599 - batch_loss: 0.1419 - avg_loss_so_far: 0.1219
#   [Epoch 6/16] Batch 1590/1599 - batch_loss: 0.0893 - avg_loss_so_far: 0.1217
#   [Epoch 6/16] Batch 1599/1599 - batch_loss: 0.1354 - avg_loss_so_far: 0.1217
# Epoch [6/16] - epoch_loss: 0.1217 - time: 1460.4s - lr: 0.001000
#   components: loss_classifier: 0.0543 | loss_box_reg: 0.0622 | loss_objectness: 0.0031 | loss_rpn_box_reg: 0.0021
#
# ===== Epoch 7/16 =====
#   [Epoch 7/16] Batch 159/1599 - batch_loss: 0.0865 - avg_loss_so_far: 0.1168
#   [Epoch 7/16] Batch 318/1599 - batch_loss: 0.2257 - avg_loss_so_far: 0.1178
#   [Epoch 7/16] Batch 477/1599 - batch_loss: 0.0847 - avg_loss_so_far: 0.1189
#   [Epoch 7/16] Batch 636/1599 - batch_loss: 0.1461 - avg_loss_so_far: 0.1181
#   [Epoch 7/16] Batch 795/1599 - batch_loss: 0.1247 - avg_loss_so_far: 0.1183
#   [Epoch 7/16] Batch 954/1599 - batch_loss: 0.0867 - avg_loss_so_far: 0.1183
#   [Epoch 7/16] Batch 1113/1599 - batch_loss: 0.0840 - avg_loss_so_far: 0.1177
#   [Epoch 7/16] Batch 1272/1599 - batch_loss: 0.1518 - avg_loss_so_far: 0.1174
#   [Epoch 7/16] Batch 1431/1599 - batch_loss: 0.1188 - avg_loss_so_far: 0.1172
#   [Epoch 7/16] Batch 1590/1599 - batch_loss: 0.1356 - avg_loss_so_far: 0.1163
#   [Epoch 7/16] Batch 1599/1599 - batch_loss: 0.1242 - avg_loss_so_far: 0.1163
# Epoch [7/16] - epoch_loss: 0.1163 - time: 1458.5s - lr: 0.001000
#   components: loss_classifier: 0.0521 | loss_box_reg: 0.0594 | loss_objectness: 0.0028 | loss_rpn_box_reg: 0.0019
#
# ===== Epoch 8/16 =====
#   [Epoch 8/16] Batch 159/1599 - batch_loss: 0.1350 - avg_loss_so_far: 0.1109
#   [Epoch 8/16] Batch 318/1599 - batch_loss: 0.1307 - avg_loss_so_far: 0.1128
#   [Epoch 8/16] Batch 477/1599 - batch_loss: 0.1207 - avg_loss_so_far: 0.1140
#   [Epoch 8/16] Batch 636/1599 - batch_loss: 0.1103 - avg_loss_so_far: 0.1135
#   [Epoch 8/16] Batch 795/1599 - batch_loss: 0.0952 - avg_loss_so_far: 0.1119
#   [Epoch 8/16] Batch 954/1599 - batch_loss: 0.1697 - avg_loss_so_far: 0.1122
#   [Epoch 8/16] Batch 1113/1599 - batch_loss: 0.0967 - avg_loss_so_far: 0.1122
#   [Epoch 8/16] Batch 1272/1599 - batch_loss: 0.1300 - avg_loss_so_far: 0.1123
#   [Epoch 8/16] Batch 1431/1599 - batch_loss: 0.0792 - avg_loss_so_far: 0.1121
#   [Epoch 8/16] Batch 1590/1599 - batch_loss: 0.1155 - avg_loss_so_far: 0.1119
#   [Epoch 8/16] Batch 1599/1599 - batch_loss: 0.0572 - avg_loss_so_far: 0.1118
# Epoch [8/16] - epoch_loss: 0.1118 - time: 1460.0s - lr: 0.001000
#   components: loss_classifier: 0.0504 | loss_box_reg: 0.0569 | loss_objectness: 0.0026 | loss_rpn_box_reg: 0.0019
#
# ===== Epoch 9/16 =====
#   [Epoch 9/16] Batch 159/1599 - batch_loss: 0.0861 - avg_loss_so_far: 0.1007
#   [Epoch 9/16] Batch 318/1599 - batch_loss: 0.1459 - avg_loss_so_far: 0.0990
#   [Epoch 9/16] Batch 477/1599 - batch_loss: 0.1734 - avg_loss_so_far: 0.0980
#   [Epoch 9/16] Batch 636/1599 - batch_loss: 0.0561 - avg_loss_so_far: 0.0990
#   [Epoch 9/16] Batch 795/1599 - batch_loss: 0.0705 - avg_loss_so_far: 0.0991
#   [Epoch 9/16] Batch 954/1599 - batch_loss: 0.0453 - avg_loss_so_far: 0.0984
#   [Epoch 9/16] Batch 1113/1599 - batch_loss: 0.0745 - avg_loss_so_far: 0.0980
#   [Epoch 9/16] Batch 1272/1599 - batch_loss: 0.0947 - avg_loss_so_far: 0.0980
#   [Epoch 9/16] Batch 1431/1599 - batch_loss: 0.0949 - avg_loss_so_far: 0.0974
#   [Epoch 9/16] Batch 1590/1599 - batch_loss: 0.0831 - avg_loss_so_far: 0.0973
#   [Epoch 9/16] Batch 1599/1599 - batch_loss: 0.0590 - avg_loss_so_far: 0.0974
# Epoch [9/16] - epoch_loss: 0.0974 - time: 1462.0s - lr: 0.000100
#   components: loss_classifier: 0.0446 | loss_box_reg: 0.0491 | loss_objectness: 0.0022 | loss_rpn_box_reg: 0.0015
#
# ===== Epoch 10/16 =====
#   [Epoch 10/16] Batch 159/1599 - batch_loss: 0.0576 - avg_loss_so_far: 0.0941
#   [Epoch 10/16] Batch 318/1599 - batch_loss: 0.0848 - avg_loss_so_far: 0.0931
#   [Epoch 10/16] Batch 477/1599 - batch_loss: 0.1331 - avg_loss_so_far: 0.0930
#   [Epoch 10/16] Batch 636/1599 - batch_loss: 0.0614 - avg_loss_so_far: 0.0945
#   [Epoch 10/16] Batch 795/1599 - batch_loss: 0.1242 - avg_loss_so_far: 0.0941
#   [Epoch 10/16] Batch 954/1599 - batch_loss: 0.0788 - avg_loss_so_far: 0.0951
#   [Epoch 10/16] Batch 1113/1599 - batch_loss: 0.0711 - avg_loss_so_far: 0.0949
#   [Epoch 10/16] Batch 1272/1599 - batch_loss: 0.0412 - avg_loss_so_far: 0.0950
#   [Epoch 10/16] Batch 1431/1599 - batch_loss: 0.0915 - avg_loss_so_far: 0.0954
#   [Epoch 10/16] Batch 1590/1599 - batch_loss: 0.0979 - avg_loss_so_far: 0.0953
#   [Epoch 10/16] Batch 1599/1599 - batch_loss: 0.0611 - avg_loss_so_far: 0.0953
# Epoch [10/16] - epoch_loss: 0.0953 - time: 1461.0s - lr: 0.000100
#   components: loss_classifier: 0.0435 | loss_box_reg: 0.0482 | loss_objectness: 0.0022 | loss_rpn_box_reg: 0.0015
#
# ===== Epoch 11/16 =====
#   [Epoch 11/16] Batch 159/1599 - batch_loss: 0.0986 - avg_loss_so_far: 0.1008
#   [Epoch 11/16] Batch 318/1599 - batch_loss: 0.0784 - avg_loss_so_far: 0.0962
#   [Epoch 11/16] Batch 477/1599 - batch_loss: 0.1212 - avg_loss_so_far: 0.0949
#   [Epoch 11/16] Batch 636/1599 - batch_loss: 0.0908 - avg_loss_so_far: 0.0946
#   [Epoch 11/16] Batch 795/1599 - batch_loss: 0.1063 - avg_loss_so_far: 0.0941
#   [Epoch 11/16] Batch 954/1599 - batch_loss: 0.0759 - avg_loss_so_far: 0.0942
#   [Epoch 11/16] Batch 1113/1599 - batch_loss: 0.0648 - avg_loss_so_far: 0.0941
#   [Epoch 11/16] Batch 1272/1599 - batch_loss: 0.1450 - avg_loss_so_far: 0.0939
#   [Epoch 11/16] Batch 1431/1599 - batch_loss: 0.0713 - avg_loss_so_far: 0.0936
#   [Epoch 11/16] Batch 1590/1599 - batch_loss: 0.0825 - avg_loss_so_far: 0.0938
#   [Epoch 11/16] Batch 1599/1599 - batch_loss: 0.1377 - avg_loss_so_far: 0.0938
# Epoch [11/16] - epoch_loss: 0.0938 - time: 1460.3s - lr: 0.000100
#   components: loss_classifier: 0.0425 | loss_box_reg: 0.0477 | loss_objectness: 0.0022 | loss_rpn_box_reg: 0.0015
#
# ===== Epoch 12/16 =====
#   [Epoch 12/16] Batch 159/1599 - batch_loss: 0.0659 - avg_loss_so_far: 0.0978
#   [Epoch 12/16] Batch 318/1599 - batch_loss: 0.1181 - avg_loss_so_far: 0.0948
#   [Epoch 12/16] Batch 477/1599 - batch_loss: 0.0726 - avg_loss_so_far: 0.0936
#   [Epoch 12/16] Batch 636/1599 - batch_loss: 0.0611 - avg_loss_so_far: 0.0937
#   [Epoch 12/16] Batch 795/1599 - batch_loss: 0.0656 - avg_loss_so_far: 0.0933
#   [Epoch 12/16] Batch 954/1599 - batch_loss: 0.0728 - avg_loss_so_far: 0.0928
#   [Epoch 12/16] Batch 1113/1599 - batch_loss: 0.0940 - avg_loss_so_far: 0.0929
#   [Epoch 12/16] Batch 1272/1599 - batch_loss: 0.0895 - avg_loss_so_far: 0.0927
#   [Epoch 12/16] Batch 1431/1599 - batch_loss: 0.0722 - avg_loss_so_far: 0.0928
#   [Epoch 12/16] Batch 1590/1599 - batch_loss: 0.0504 - avg_loss_so_far: 0.0927
#   [Epoch 12/16] Batch 1599/1599 - batch_loss: 0.1459 - avg_loss_so_far: 0.0928
# Epoch [12/16] - epoch_loss: 0.0928 - time: 1461.0s - lr: 0.000100
#   components: loss_classifier: 0.0422 | loss_box_reg: 0.0470 | loss_objectness: 0.0021 | loss_rpn_box_reg: 0.0015
#
# ===== Epoch 13/16 =====
#   [Epoch 13/16] Batch 159/1599 - batch_loss: 0.1303 - avg_loss_so_far: 0.0891
#   [Epoch 13/16] Batch 318/1599 - batch_loss: 0.0893 - avg_loss_so_far: 0.0893
#   [Epoch 13/16] Batch 477/1599 - batch_loss: 0.1174 - avg_loss_so_far: 0.0913
#   [Epoch 13/16] Batch 636/1599 - batch_loss: 0.0676 - avg_loss_so_far: 0.0907
#   [Epoch 13/16] Batch 795/1599 - batch_loss: 0.0594 - avg_loss_so_far: 0.0903
#   [Epoch 13/16] Batch 954/1599 - batch_loss: 0.0794 - avg_loss_so_far: 0.0910
#   [Epoch 13/16] Batch 1113/1599 - batch_loss: 0.0995 - avg_loss_so_far: 0.0918
#   [Epoch 13/16] Batch 1272/1599 - batch_loss: 0.0689 - avg_loss_so_far: 0.0920
#   [Epoch 13/16] Batch 1431/1599 - batch_loss: 0.1702 - avg_loss_so_far: 0.0920
#   [Epoch 13/16] Batch 1590/1599 - batch_loss: 0.0864 - avg_loss_so_far: 0.0916
#   [Epoch 13/16] Batch 1599/1599 - batch_loss: 0.0515 - avg_loss_so_far: 0.0915
# Epoch [13/16] - epoch_loss: 0.0915 - time: 1461.6s - lr: 0.000100
#   components: loss_classifier: 0.0413 | loss_box_reg: 0.0467 | loss_objectness: 0.0021 | loss_rpn_box_reg: 0.0015
#
# ===== Epoch 14/16 =====
#   [Epoch 14/16] Batch 159/1599 - batch_loss: 0.1537 - avg_loss_so_far: 0.0920
#   [Epoch 14/16] Batch 318/1599 - batch_loss: 0.0964 - avg_loss_so_far: 0.0911
#   [Epoch 14/16] Batch 477/1599 - batch_loss: 0.1863 - avg_loss_so_far: 0.0908
#   [Epoch 14/16] Batch 636/1599 - batch_loss: 0.0573 - avg_loss_so_far: 0.0914
#   [Epoch 14/16] Batch 795/1599 - batch_loss: 0.0730 - avg_loss_so_far: 0.0915
#   [Epoch 14/16] Batch 954/1599 - batch_loss: 0.1006 - avg_loss_so_far: 0.0911
#   [Epoch 14/16] Batch 1113/1599 - batch_loss: 0.0858 - avg_loss_so_far: 0.0906
#   [Epoch 14/16] Batch 1272/1599 - batch_loss: 0.1379 - avg_loss_so_far: 0.0905
#   [Epoch 14/16] Batch 1431/1599 - batch_loss: 0.0773 - avg_loss_so_far: 0.0907
#   [Epoch 14/16] Batch 1590/1599 - batch_loss: 0.1292 - avg_loss_so_far: 0.0906
#   [Epoch 14/16] Batch 1599/1599 - batch_loss: 0.0863 - avg_loss_so_far: 0.0908
# Epoch [14/16] - epoch_loss: 0.0908 - time: 1462.2s - lr: 0.000100
#   components: loss_classifier: 0.0411 | loss_box_reg: 0.0461 | loss_objectness: 0.0021 | loss_rpn_box_reg: 0.0015
#
# ===== Epoch 15/16 =====
#   [Epoch 15/16] Batch 159/1599 - batch_loss: 0.2786 - avg_loss_so_far: 0.0920
#   [Epoch 15/16] Batch 318/1599 - batch_loss: 0.0846 - avg_loss_so_far: 0.0907
#   [Epoch 15/16] Batch 477/1599 - batch_loss: 0.1336 - avg_loss_so_far: 0.0910
#   [Epoch 15/16] Batch 636/1599 - batch_loss: 0.0631 - avg_loss_so_far: 0.0908
#   [Epoch 15/16] Batch 795/1599 - batch_loss: 0.0763 - avg_loss_so_far: 0.0904
#   [Epoch 15/16] Batch 954/1599 - batch_loss: 0.0923 - avg_loss_so_far: 0.0904
#   [Epoch 15/16] Batch 1113/1599 - batch_loss: 0.1052 - avg_loss_so_far: 0.0906
#   [Epoch 15/16] Batch 1272/1599 - batch_loss: 0.0795 - avg_loss_so_far: 0.0904
#   [Epoch 15/16] Batch 1431/1599 - batch_loss: 0.1115 - avg_loss_so_far: 0.0898
#   [Epoch 15/16] Batch 1590/1599 - batch_loss: 0.0879 - avg_loss_so_far: 0.0902
#   [Epoch 15/16] Batch 1599/1599 - batch_loss: 0.0735 - avg_loss_so_far: 0.0902
# Epoch [15/16] - epoch_loss: 0.0902 - time: 1460.5s - lr: 0.000100
#   components: loss_classifier: 0.0409 | loss_box_reg: 0.0459 | loss_objectness: 0.0021 | loss_rpn_box_reg: 0.0014
#
# ===== Epoch 16/16 =====
#   [Epoch 16/16] Batch 159/1599 - batch_loss: 0.1182 - avg_loss_so_far: 0.0882
#   [Epoch 16/16] Batch 318/1599 - batch_loss: 0.0863 - avg_loss_so_far: 0.0897
#   [Epoch 16/16] Batch 477/1599 - batch_loss: 0.0571 - avg_loss_so_far: 0.0900
#   [Epoch 16/16] Batch 636/1599 - batch_loss: 0.1271 - avg_loss_so_far: 0.0898
#   [Epoch 16/16] Batch 795/1599 - batch_loss: 0.1074 - avg_loss_so_far: 0.0898
#   [Epoch 16/16] Batch 954/1599 - batch_loss: 0.0632 - avg_loss_so_far: 0.0898
#   [Epoch 16/16] Batch 1113/1599 - batch_loss: 0.0905 - avg_loss_so_far: 0.0897
#   [Epoch 16/16] Batch 1272/1599 - batch_loss: 0.0753 - avg_loss_so_far: 0.0897
#   [Epoch 16/16] Batch 1431/1599 - batch_loss: 0.0854 - avg_loss_so_far: 0.0895
#   [Epoch 16/16] Batch 1590/1599 - batch_loss: 0.0788 - avg_loss_so_far: 0.0894
#   [Epoch 16/16] Batch 1599/1599 - batch_loss: 0.1219 - avg_loss_so_far: 0.0895
# Epoch [16/16] - epoch_loss: 0.0895 - time: 1460.9s - lr: 0.000100
#   components: loss_classifier: 0.0406 | loss_box_reg: 0.0455 | loss_objectness: 0.0021 | loss_rpn_box_reg: 0.0014
#
# Total training time: 389.12 minutes

# %%
import torch

torch.save(model.state_dict(), "/kaggle/working/my_model_weights.pth")
print("saved to /kaggle/working/my_model_weights.pth")
# Out:
# saved to /kaggle/working/my_model_weights.pth

# %%
import os
import json
import torch

MODEL_OUTPUT_DIR = "/kaggle/working/retinanet_artifacts"
os.makedirs(MODEL_OUTPUT_DIR, exist_ok=True)

run_name = "retinanet_r50_mosquito_20ep"

# 1) save model weights (state_dict-only, easiest for loading later)
weights_path = os.path.join(MODEL_OUTPUT_DIR, f"{run_name}_weights.pth")
torch.save(model.state_dict(), weights_path)
print("Saved weights to:", weights_path)

# 2) optionally, save a full checkpoint (weights + optimizer + history)
ckpt_path = os.path.join(MODEL_OUTPUT_DIR, f"{run_name}_full_ckpt.pth")
torch.save(
    {
        "epoch": num_epochs,
        "model_state_dict": model.state_dict(),
        "optimizer_state_dict": optimizer.state_dict(),
        "history": history,
        "config": {
            "num_classes": num_classes,
            "img_size": IMG_SIZE,
            "classes": classes,
        },
    },
    ckpt_path,
)
print("Saved full checkpoint to:", ckpt_path)

# 3) JSON metadata for your app / dashboards
meta_path = os.path.join(MODEL_OUTPUT_DIR, f"{run_name}_meta.json")
with open(meta_path, "w") as f:
    json.dump(
        {
            "run_name": run_name,
            "num_epochs": num_epochs,
            "total_train_time_sec": total_time,
            "num_classes": num_classes,
            "img_size": IMG_SIZE,
            "classes": classes,
            "history": history,
        },
        f,
        indent=2,
    )
print("Saved metadata to:", meta_path)
# Out:
# Saved weights to: /kaggle/working/retinanet_artifacts/retinanet_r50_mosquito_20ep_weights.pth
# Saved full checkpoint to: /kaggle/working/retinanet_artifacts/retinanet_r50_mosquito_20ep_full_ckpt.pth
# Saved metadata to: /kaggle/working/retinanet_artifacts/retinanet_r50_mosquito_20ep_meta.json
